# %%
# Application Settings
enable_trueRandom = False
num_rolls = 1000000
file_dataset = "rolls.csv"

# %%
# Static imports
# Out:
# [7, 22, 76, 84, 27, 10, 18, 50, 21, 2, 33, 17, 83, 73, 87, 53, 6, 24, 37, 32, 82, 34, 23, 16, 59, 58, 51, 35, 26, 61, 54, 30, 66, 45, 38, 36, 25, 11, 49, 3, 52, 89, 20, 5, 42, 8, 43, 48, 67, 56, 19, 28, 71, 57, 15, 75, 81, 69, 72, 31, 68, 4, 70, 86, 74, 39, 65, 88, 64, 47, 46, 79, 13, 78, 44, 60, 63, 9, 41, 12]
